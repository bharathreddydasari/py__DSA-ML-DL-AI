# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\dasarred\Documents\duplicates.csv')

# %%
df
# Out:
#    A  B    C    D  E
# 0  1  5  5.0  1.0  1
# 1  2  4  4.0  NaN  1
# 2  3  3  1.0  3.0  1
# 3  4  2  NaN  5.0  1
# 4  5  1  3.0  4.0  1

# %%
df.style.highlight_null(null_color='red')
# Out:
# <style  type="text/css" >
#     #T_ce982142_7a93_11e8_b33f_f0d5bf6dc17frow1_col3 {
#             background-color:  red;
#         }    #T_ce982142_7a93_11e8_b33f_f0d5bf6dc17frow3_col2 {
#             background-color:  red;
#         }</style>
# <table id="T_ce982142_7a93_11e8_b33f_f0d5bf6dc17f" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >A</th>
#         <th class="col_heading level0 col1" >B</th>
#         <th class="col_heading level0 col2" >C</th>
#         <th class="col_heading level0 col3" >D</th>
#         <th class="col_heading level0 col4" >E</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ce982142_7a93_11e8_b33f_f0d5bf6dc17flevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_ce982142_7a93_11e8_b33f_f0d5bf6dc17frow0_col0" class="data row0 col0" >1</td>
#         <td id="T_ce982142_7a93_11e8_b33f_f0d5bf6dc17frow0_col1" class="data row0 col1" >5</td>
# ...

# %%
df.style.set_table_styles([{'selector':'thead',
                              'props':[('background-color','yellow'),
                                        ('color','green'),
                                          ('font-size','20px')]},
                              {'selector':'tbody>tr>th',
                                  'props':[('background-color','red')]},
                               {'selector':'thead>tr>th:first-child',
                                   'props':[('background-color','gray')]},
                              {'selector':'tbody>tr>td',
                                  'props':[('background-color','rgba(0,0,255,0.5)')]}])
# Out:
# <style  type="text/css" >
#     #T_55f8faf4_7a95_11e8_8dc4_f0d5bf6dc17f thead {
#           background-color: yellow;
#           color: green;
#           font-size: 20px;
#     }    #T_55f8faf4_7a95_11e8_8dc4_f0d5bf6dc17f tbody>tr>th {
#           background-color: red;
#     }    #T_55f8faf4_7a95_11e8_8dc4_f0d5bf6dc17f thead>tr>th:first-child {
#           background-color: gray;
#     }    #T_55f8faf4_7a95_11e8_8dc4_f0d5bf6dc17f tbody>tr>td {
#           background-color: rgba(0,0,255,0.5);
#     }</style>
# <table id="T_55f8faf4_7a95_11e8_8dc4_f0d5bf6dc17f" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >A</th>
#         <th class="col_heading level0 col1" >B</th>
#         <th class="col_heading level0 col2" >C</th>
#         <th class="col_heading level0 col3" >D</th>
#         <th class="col_heading level0 col4" >E</th>
#     </tr></thead>
# <tbody>    <tr>
# ...

# %%
df.style.set_properties(**{'background-color': 'black',
                           'color': 'lawngreen',
                           'border-color': 'white'})
# Out:
# <style  type="text/css" >
#     #T_8b5669e4_7a95_11e8_8d1f_f0d5bf6dc17frow0_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_8b5669e4_7a95_11e8_8d1f_f0d5bf6dc17frow0_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_8b5669e4_7a95_11e8_8d1f_f0d5bf6dc17frow0_col2 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_8b5669e4_7a95_11e8_8d1f_f0d5bf6dc17frow0_col3 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_8b5669e4_7a95_11e8_8d1f_f0d5bf6dc17frow0_col4 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_8b5669e4_7a95_11e8_8d1f_f0d5bf6dc17frow1_col0 {
#             background-color:  black;
# ...

# %% [raw]
# axis = 1 ==> Row
# axis = 0 ==> Column

# %%
df.style.highlight_max(axis=1)#Highlight row wise large value
# Out:
# <style  type="text/css" >
#     #T_77d3d952_7a96_11e8_9025_f0d5bf6dc17frow0_col1 {
#             background-color:  yellow;
#         }    #T_77d3d952_7a96_11e8_9025_f0d5bf6dc17frow0_col2 {
#             background-color:  yellow;
#         }    #T_77d3d952_7a96_11e8_9025_f0d5bf6dc17frow1_col1 {
#             background-color:  yellow;
#         }    #T_77d3d952_7a96_11e8_9025_f0d5bf6dc17frow1_col2 {
#             background-color:  yellow;
#         }    #T_77d3d952_7a96_11e8_9025_f0d5bf6dc17frow2_col0 {
#             background-color:  yellow;
#         }    #T_77d3d952_7a96_11e8_9025_f0d5bf6dc17frow2_col1 {
#             background-color:  yellow;
#         }    #T_77d3d952_7a96_11e8_9025_f0d5bf6dc17frow2_col3 {
#             background-color:  yellow;
#         }    #T_77d3d952_7a96_11e8_9025_f0d5bf6dc17frow3_col3 {
#             background-color:  yellow;
#         }    #T_77d3d952_7a96_11e8_9025_f0d5bf6dc17frow4_col0 {
#             background-color:  yellow;
# ...

# %%
df.style.highlight_max(axis=0)#Highlight column wise large value
# Out:
# <style  type="text/css" >
#     #T_7827536e_7a96_11e8_920b_f0d5bf6dc17frow0_col1 {
#             background-color:  yellow;
#         }    #T_7827536e_7a96_11e8_920b_f0d5bf6dc17frow0_col2 {
#             background-color:  yellow;
#         }    #T_7827536e_7a96_11e8_920b_f0d5bf6dc17frow0_col4 {
#             background-color:  yellow;
#         }    #T_7827536e_7a96_11e8_920b_f0d5bf6dc17frow1_col4 {
#             background-color:  yellow;
#         }    #T_7827536e_7a96_11e8_920b_f0d5bf6dc17frow2_col4 {
#             background-color:  yellow;
#         }    #T_7827536e_7a96_11e8_920b_f0d5bf6dc17frow3_col3 {
#             background-color:  yellow;
#         }    #T_7827536e_7a96_11e8_920b_f0d5bf6dc17frow3_col4 {
#             background-color:  yellow;
#         }    #T_7827536e_7a96_11e8_920b_f0d5bf6dc17frow4_col0 {
#             background-color:  yellow;
#         }    #T_7827536e_7a96_11e8_920b_f0d5bf6dc17frow4_col4 {
#             background-color:  yellow;
# ...

# %%
df.style.highlight_min(axis=1)#Highlight row wise low value
# Out:
# <style  type="text/css" >
#     #T_786c8b58_7a96_11e8_b328_f0d5bf6dc17frow0_col0 {
#             background-color:  yellow;
#         }    #T_786c8b58_7a96_11e8_b328_f0d5bf6dc17frow0_col3 {
#             background-color:  yellow;
#         }    #T_786c8b58_7a96_11e8_b328_f0d5bf6dc17frow0_col4 {
#             background-color:  yellow;
#         }    #T_786c8b58_7a96_11e8_b328_f0d5bf6dc17frow1_col4 {
#             background-color:  yellow;
#         }    #T_786c8b58_7a96_11e8_b328_f0d5bf6dc17frow2_col2 {
#             background-color:  yellow;
#         }    #T_786c8b58_7a96_11e8_b328_f0d5bf6dc17frow2_col4 {
#             background-color:  yellow;
#         }    #T_786c8b58_7a96_11e8_b328_f0d5bf6dc17frow3_col4 {
#             background-color:  yellow;
#         }    #T_786c8b58_7a96_11e8_b328_f0d5bf6dc17frow4_col1 {
#             background-color:  yellow;
#         }    #T_786c8b58_7a96_11e8_b328_f0d5bf6dc17frow4_col4 {
#             background-color:  yellow;
# ...

# %%
df.loc[:4].style.background_gradient(cmap='viridis')
# Out:
# C:\Users\dasarred\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_78bd95a4_7a96_11e8_bb5a_f0d5bf6dc17frow0_col0 {
#             background-color:  #440154;
#         }    #T_78bd95a4_7a96_11e8_bb5a_f0d5bf6dc17frow0_col1 {
#             background-color:  #fde725;
#         }    #T_78bd95a4_7a96_11e8_bb5a_f0d5bf6dc17frow0_col2 {
#             background-color:  #fde725;
#         }    #T_78bd95a4_7a96_11e8_bb5a_f0d5bf6dc17frow0_col3 {
#             background-color:  #440154;
#         }    #T_78bd95a4_7a96_11e8_bb5a_f0d5bf6dc17frow0_col4 {
#             background-color:  #440154;
#         }    #T_78bd95a4_7a96_11e8_bb5a_f0d5bf6dc17frow1_col0 {
#             background-color:  #3b528b;
#         }    #T_78bd95a4_7a96_11e8_bb5a_f0d5bf6dc17frow1_col1 {
#             background-color:  #5ec962;
# ...

# %%
df
# Out:
#    A  B    C    D  E
# 0  1  5  5.0  1.0  1
# 1  2  4  4.0  NaN  1
# 2  3  3  1.0  3.0  1
# 3  4  2  NaN  5.0  1
# 4  5  1  3.0  4.0  1

# %%
df.shape
# Out:
# (5, 5)

# %%
df.loc[df.duplicated(subset=['B','C'],keep='last')]
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E]
# Index: []

# %%
df.loc[df.duplicated(subset=['A','B'],keep='last')]
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E]
# Index: []

# %%
df.drop_duplicates(subset=['A','B'],keep='last')
# Out:
#    A  B    C    D  E
# 0  1  5  5.0  1.0  1
# 1  2  4  4.0  NaN  1
# 2  3  3  1.0  3.0  1
# 3  4  2  NaN  5.0  1
# 4  5  1  3.0  4.0  1

# %%
df.transpose
# Out:
# <bound method DataFrame.transpose of    A  B    C    D  E
# 0  1  5  5.0  1.0  1
# 1  2  4  4.0  NaN  1
# 2  3  3  1.0  3.0  1
# 3  4  2  NaN  5.0  1
# 4  5  1  3.0  4.0  1>

# %%
df1 = df.fillna('25')

# %%
df1
# Out:
#    A  B   C   D  E
# 0  1  5   5   1  1
# 1  2  4   4  25  1
# 2  3  3   1   3  1
# 3  4  2  25   5  1
# 4  5  1   3   4  1

# %%
df1.values
# Out:
# array([[1, 5, 5.0, 1.0, 1],
#        [2, 4, 4.0, '25', 1],
#        [3, 3, 1.0, 3.0, 1],
#        [4, 2, '25', 5.0, 1],
#        [5, 1, 3.0, 4.0, 1]], dtype=object)

# %%
df1.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df1corr = df1.corr()

# %%
df1corr
# Out:
#      A    B   E
# A  1.0 -1.0 NaN
# B -1.0  1.0 NaN
# E  NaN  NaN NaN
